# %% [markdown]
# # 4.3 Array-Oriented Programming with Arrays

# %%
import numpy as np

# %%
points = np.arange(-5, 5, 0.01)

# %%
xs, ys = np.meshgrid(points, points)

# %%
ys
# Out:
# array([[-5.  , -5.  , -5.  , ..., -5.  , -5.  , -5.  ],
#        [-4.99, -4.99, -4.99, ..., -4.99, -4.99, -4.99],
#        [-4.98, -4.98, -4.98, ..., -4.98, -4.98, -4.98],
#        ...,
#        [ 4.97,  4.97,  4.97, ...,  4.97,  4.97,  4.97],
#        [ 4.98,  4.98,  4.98, ...,  4.98,  4.98,  4.98],
#        [ 4.99,  4.99,  4.99, ...,  4.99,  4.99,  4.99]])

# %%
z = np.sqrt(xs ** 2 + ys ** 2)

# %%
z
# Out:
# array([[7.07106781, 7.06400028, 7.05693985, ..., 7.04988652, 7.05693985,
#         7.06400028],
#        [7.06400028, 7.05692568, 7.04985815, ..., 7.04279774, 7.04985815,
#         7.05692568],
#        [7.05693985, 7.04985815, 7.04278354, ..., 7.03571603, 7.04278354,
#         7.04985815],
#        ...,
#        [7.04988652, 7.04279774, 7.03571603, ..., 7.0286414 , 7.03571603,
#         7.04279774],
#        [7.05693985, 7.04985815, 7.04278354, ..., 7.03571603, 7.04278354,
#         7.04985815],
#        [7.06400028, 7.05692568, 7.04985815, ..., 7.04279774, 7.04985815,
#         7.05692568]])

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(z, cmap=plt.cm.gray); plt.colorbar()

# %%
plt.title("Image plot of $\sqrt{x^2 + y^2}$ for a grid of values")
# Out:
# Text(0.5, 1.0, 'Image plot of $\\sqrt{x^2 + y^2}$ for a grid of values')

# %%
plt.imshow(z, cmap=plt.cm.gray); plt.colorbar()
plt.title("Image plot of $\sqrt{x^2 + y^2}$ for a grid of values")
# Out:
# Text(0.5, 1.0, 'Image plot of $\\sqrt{x^2 + y^2}$ for a grid of values')

# %% [markdown]
# # Expressing Conditional Logic as Array Operations

# %%
xarr = np.array([1.1, 1.2, 1.3, 1.4, 1.5])

# %%
yarr = np.array([2.1, 2.2, 2.3, 2.4, 2.5])

# %%
cond = np.array([True, False, True, True, False])

# %%
result = [(x if c else y)
          for x, y, c in zip(xarr, yarr, cond)]

# %%
result
# Out:
# [1.1, 2.2, 1.3, 1.4, 2.5]

# %%
arr = np.random.randn(4, 4)

# %%
arr
# Out:
# array([[-0.0784439 ,  0.79384878,  0.42033083,  0.88836881],
#        [-0.88944522,  0.6007783 ,  0.124928  , -0.61907475],
#        [-0.26460511,  2.19993679, -0.35044422, -0.66579923],
#        [-0.68107369, -1.59586718,  1.0084    ,  0.73788368]])

# %%
arr > 0
# Out:
# array([[False,  True,  True,  True],
#        [False,  True,  True, False],
#        [False,  True, False, False],
#        [False, False,  True,  True]])

# %%
np.where(arr > 0, 2, -2)
# Out:
# array([[-2,  2,  2,  2],
#        [-2,  2,  2, -2],
#        [-2,  2, -2, -2],
#        [-2, -2,  2,  2]])

# %%
np.where(arr > 0, 2, arr)
# Out:
# array([[-0.0784439 ,  2.        ,  2.        ,  2.        ],
#        [-0.88944522,  2.        ,  2.        , -0.61907475],
#        [-0.26460511,  2.        , -0.35044422, -0.66579923],
#        [-0.68107369, -1.59586718,  2.        ,  2.        ]])
